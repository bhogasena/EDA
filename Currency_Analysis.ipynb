# %% [markdown]
# <a href="https://colab.research.google.com/github/bhogasena/EDA/blob/main/Currency_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
cur_df = pd.read_csv('currencies.csv')

# %%
cur_df.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula  Brazilian Real  Brunei Dollar  Canadian Dollar  \
# ...

# %%
cur_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Currency                    11 non-null     object
#  1   Chinese Yuan                11 non-null     float64
#  2   Euro                        11 non-null     float64
#  3   Japanese Yen                10 non-null     float64
#  4   U.K. Pound Sterling         11 non-null     float64
#  5   U.S. Dollar                 11 non-null     float64
#  6   Algerian Dinar              9 non-null      float64
#  7   Australian Dollar           11 non-null     float64
#  8   Bahrain Dinar               11 non-null     float64
#  9   Botswana Pula               9 non-null      float64
#  10  Brazilian Real              11 non-null     float64
#  11  Brunei Dollar               10 non-null     float64
#  12  Canadian Dollar             10 non-null     float64
# ...

# %%
corr = cur_df.corr()
corr.style.background_gradient(cmap='Greens').set_precision(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %%
import matplotlib.pyplot as plt
plt.matshow(cur_df.corr())
plt.show()

# %%
corr1 = cur_df[list(['Indian Rupee','Australian Dollar','U.S. Dollar','Japanese Yen','Euro'])].corr()
corr1.style.background_gradient(cmap='Greens').set_precision(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
# <style type="text/css">
# #T_6e9e5_row0_col0, #T_6e9e5_row1_col1, #T_6e9e5_row2_col2, #T_6e9e5_row3_col3, #T_6e9e5_row4_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_6e9e5_row0_col1 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_6e9e5_row0_col2 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_6e9e5_row0_col3 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_6e9e5_row0_col4 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_6e9e5_row1_col0 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_6e9e5_row1_col2 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_6e9e5_row1_col3 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_6e9e5_row1_col4 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_6e9e5_row2_col0 {
# ...

# %%
corr2 = cur_df[['Indian Rupee','Australian Dollar','U.S. Dollar','Japanese Yen','Euro','U.K. Pound Sterling','Chinese Yuan']].corr()
corr2.style.background_gradient(cmap='Greens').set_precision(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
# <style type="text/css">
# #T_71ab8_row0_col0, #T_71ab8_row1_col1, #T_71ab8_row2_col2, #T_71ab8_row3_col3, #T_71ab8_row4_col4, #T_71ab8_row5_col5, #T_71ab8_row6_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_71ab8_row0_col1 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_71ab8_row0_col2 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_71ab8_row0_col3 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_71ab8_row0_col4 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_71ab8_row0_col5 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_71ab8_row0_col6 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_71ab8_row1_col0 {
#   background-color: #005723;
#   color: #f1f1f1;
# }
# #T_71ab8_row1_col2 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# ...

# %%
nas_df = pd.read_csv("nas.csv")

# %%
nas_df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  Mother.edu  \
# 0            2.0   1 sibling       No      Illiterate  Illiterate
# 1            2.0  3 siblings       No             NaN  Illiterate
# 2            2.0  3 siblings       No  Degree & above  Illiterate
# 3            2.0  3 siblings       No       Secondary   Secondary
# 4            2.0  2 siblings       No         Primary  Illiterate
#
#   Father.occupation Mother.occupation Below.poverty Use.calculator  \
# 0            Farmer            Farmer           Yes            NaN
# ...

# %%
import numpy as np

# %%
nas_df.pivot_table(index='Mother.edu',columns='Siblings',values='STUID',aggfunc='count')
# Out:
# Siblings        1 sibling  2 siblings  3 siblings  4+ siblings  Single child
# Mother.edu
# Degree & above         88          36          11            6            20
# Illiterate            533         923         532          469            88
# Primary               689         771         417          251            92
# Secondary            1050         846         348          255            92
# Sr secondary          206         132          48           23            24

# %%
pd.crosstab(nas_df['Mother.edu'],nas_df['Siblings'])
# Out:
# Siblings        1 sibling  2 siblings  3 siblings  4+ siblings  Single child
# Mother.edu
# Degree & above         88          36          11            6            20
# Illiterate            533         923         532          469            88
# Primary               689         771         417          251            92
# Secondary            1050         846         348          255            92
# Sr secondary          206         132          48           23            24

# %%
nas_df_plot = nas_df.groupby(['Mother.edu','Siblings']).size().reset_index().pivot(columns='Siblings',index='Mother.edu',values=0)
nas_df_plot.plot(kind='bar',stacked=True)

# %%
nas_df_plot.shape
# Out:
# (5, 5)

# %%
nas_df_plot.head()
# Out:
# Siblings        1 sibling  2 siblings  3 siblings  4+ siblings  Single child
# Mother.edu
# Degree & above         88          36          11            6            20
# Illiterate            533         923         532          469            88
# Primary               689         771         417          251            92
# Secondary            1050         846         348          255            92
# Sr secondary          206         132          48           23            24

# %%
nas_df_3 = nas_df.groupby(['Mother.edu','Siblings']).size().reset_index()

# %%
nas_df_3.head()
# Out:
#        Mother.edu      Siblings   0
# 0  Degree & above     1 sibling  88
# 1  Degree & above    2 siblings  36
# 2  Degree & above    3 siblings  11
# 3  Degree & above   4+ siblings   6
# 4  Degree & above  Single child  20

# %%
nas_df['Age'].unique()
# Out:
# array(['13 years', '15 years', '14 years', nan, '12 years', '16+ years',
#        '11- years'], dtype=object)

# %%
nas_non_11 = nas_df[nas_df['Age']!='11- years']

# %%
nas_non_11.shape
# Out:
# (8785, 64)

# %%
nas_non_11.pivot_table(index='Father.edu',columns='Age',values='Science..',aggfunc='mean')
# Out:
# Age              12 years   13 years   14 years   15 years  16+ years
# Father.edu
# Degree & above  46.752857  44.805143  42.676944  29.090000  32.730000
# Illiterate      29.870000  33.758968  35.319478  33.413333  33.116786
# Primary         34.121667  37.617555  36.700267  35.162768  32.364000
# Secondary       33.593810  38.164402  36.738859  32.872800  30.960000
# Sr secondary    40.113750  39.046503  39.050278  38.615714  31.513333
